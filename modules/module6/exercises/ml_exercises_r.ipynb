# %% [markdown]
# # Machine Learning Exercise with `R`
#
# There is still a lot to learn about machine learning, and it is important to recognize that we have barely started to scrape the surface of it. There are many things we could do to refine our model that we didn't touch on in this module (don't worry, these will be covered throughout your curriculum), such as data transformation, elegant methods for automated feature selection, as well as unsupervised learning.
#
# For these exercises, we ask you to only complete **ONE** of the exercise notebooks, either `Python` or `R`. We will be asking you to predict wine quality using both Decision Tree and Naïve Bayes. Your exercises will serve as a sort-of extended practice in which you are free to try and refine the model however you see fit, but we do ask you to use both Decision Tree and Naïve Bayes.
#
# The questions will guide you a bit, but if you want to experiment or you find, through data exploration, a model that is better, feel free to do so. If you go this route, leave comments in the code justifying why you did what you did.

# %% [markdown]
# ### Read in Packages

# %%
library(tree)
library(ggplot2)
library(e1071)

# %% [markdown]
# ### Read in the Data
#
# Today we will be using the Red Wine Quality data. The target variable is numeric, so we are going to discretize it a bit before we get to the activities.

# %%
wine <- read.csv('/dsa/data/all_datasets/wine-quality/winequality-red.csv', sep = ";")
wine
# Out:
#      fixed.acidity volatile.acidity citric.acid residual.sugar chlorides
# 1     7.4          0.700            0.00        1.9            0.076
# 2     7.8          0.880            0.00        2.6            0.098
# 3     7.8          0.760            0.04        2.3            0.092
# 4    11.2          0.280            0.56        1.9            0.075
# 5     7.4          0.700            0.00        1.9            0.076
# 6     7.4          0.660            0.00        1.8            0.075
# 7     7.9          0.600            0.06        1.6            0.069
# 8     7.3          0.650            0.00        1.2            0.065
# 9     7.8          0.580            0.02        2.0            0.073
# 10    7.5          0.500            0.36        6.1            0.071
# 11    6.7          0.580            0.08        1.8            0.097
# 12    7.5          0.500            0.36        6.1            0.071
# 13    5.6          0.615            0.00        1.6            0.089
# 14    7.8          0.610            0.29        1.6            0.114
# 15    8.9          0.620            0.18        3.8            0.176
# 16    8.9          0.620            0.19        3.9            0.170
# 17    8.5          0.280            0.56        1.8            0.092
# 18    8.1          0.560            0.28        1.7            0.368
# 19    7.4          0.590            0.08        4.4            0.086
# 20    7.9          0.320            0.51        1.8            0.341
# 21    8.9          0.220            0.48        1.8            0.077
# 22    7.6          0.390            0.31        2.3            0.082
# 23    7.9          0.430            0.21        1.6            0.106
# 24    8.5          0.490            0.11        2.3            0.084
# 25    6.9          0.400            0.14        2.4            0.085
# 26    6.3          0.390            0.16        1.4            0.080
# 27    7.6          0.410            0.24        1.8            0.080
# 28    7.9          0.430            0.21        1.6            0.106
# 29    7.1          0.710            0.00        1.9            0.080
# 30    7.8          0.645            0.00        2.0            0.082
# ⋮    ⋮             ⋮                ⋮           ⋮              ⋮
# 1570 6.2           0.510            0.14         1.9           0.056
# 1571 6.4           0.360            0.53         2.2           0.230
# 1572 6.4           0.380            0.14         2.2           0.038
# 1573 7.3           0.690            0.32         2.2           0.069
# 1574 6.0           0.580            0.20         2.4           0.075
# 1575 5.6           0.310            0.78        13.9           0.074
# 1576 7.5           0.520            0.40         2.2           0.060
# 1571 19                   35                  0.99340 3.37 0.93      12.4
# 1572 15                   25                  0.99514 3.44 0.65      11.1
# 1573 35                  104                  0.99632 3.33 0.51       9.5
# 1574 15                   50                  0.99467 3.58 0.67      12.5
# 1575 23                   92                  0.99677 3.39 0.48      10.5
# 1576 12                   20                  0.99474 3.26 0.64      11.8
# 1577 16                   29                  0.99588 3.30 0.78      10.8
# 1578 13                   27                  0.99622 3.54 0.60      11.9
# 1579 13                   20                  0.99540 3.42 0.67      11.3
# 1580 24                   32                  0.99402 3.54 0.60      11.3
# 1581  9                   26                  0.99470 3.36 0.60      11.9
# 1582 24                   32                  0.99402 3.54 0.60      11.3
# 1583 13                   27                  0.99362 3.57 0.50      11.9
# 1584 32                   98                  0.99578 3.33 0.62       9.8
# 1585 24                   34                  0.99484 3.29 0.80      11.6
# 1586 22                   48                  0.99494 3.30 0.84      11.5
# 1587 34                   60                  0.99492 3.34 0.85      11.4
# 1588 18                   28                  0.99483 3.55 0.66      10.9
# 1589 34                  102                  0.99414 3.27 0.78      12.8
# 1590 29                   79                  0.99770 3.29 0.54       9.2
# 1591 26                   35                  0.99314 3.32 0.82      11.6
# 1592 16                   26                  0.99402 3.67 0.56      11.6
# 1593 29                   40                  0.99574 3.42 0.75      11.0
# 1594 28                   38                  0.99651 3.42 0.82       9.5
# 1595 32                   44                  0.99490 3.45 0.58      10.5
# 1596 39                   51                  0.99512 3.52 0.76      11.2
# 1597 29                   40                  0.99574 3.42 0.75      11.0
# 1598 32                   44                  0.99547 3.57 0.71      10.2
# 1599 18                   42                  0.99549 3.39 0.66      11.0
#      quality
# 1    5
# 2    5
# 3    5
# 4    6
# 5    5
# 6    5
# 7    5
# 8    7
# 9    7
# 10   5
# 11   5
# 12   5
# 13   5
# 14   5
# 15   5
# 16   5
# 17   7
# 18   5
# 19   4
# 20   6
# 21   6
# 22   5
# 23   5
# 24   5
# 25   6
# 26   5
# 27   5
# 28   5
# 29   5
# 30   6
# ⋮    ⋮
# 1570 6
# 1571 6
# 1572 6
# 1573 5
# 1574 6
# 1575 6
# 1576 6
# 1577 6
# 1578 6
# 1579 6
# 1580 5
# 1581 6
# 1582 5
# 1583 5
# 1584 5
# 1585 7
# 1586 6
# 1587 6
# 1588 6
# 1589 6
# 1590 5
# 1591 6
# 1592 6
# 1593 6
# 1594 6
# 1595 5
# 1596 6
# 1597 6
# 1598 5
# 1599 6

# %%
# if wine quality is less than 6, assign the value "bad".
# if 6 or greater, assign "good". create a new target called
# taste
wine$taste <- ifelse(wine$quality < 6, 'bad', 'good') 

# 6 is the most popular value by a lot in this set, so 
# we are going to assign it a unique value. We will call 
# this "normal" as it is in the middle of the distribution.
wine$taste[wine$quality == 6] <- 'normal'

# make this target variable categorical
wine$taste <- as.factor(wine$taste)

# remove the old target, since it is no longer needed
wine <- wine[,-12]

# %% [markdown]
# **Exercise 1**: Create a training data set and testing data set from the `wine` data frame. Make sure that the rows are randomly selected. The training set should be constructed from 60% of the data; call it `train`. The testing set should be called `test` and should be constructed from the **other** 40% of the data. Be sure to pass `123` as the set.seed() first.

# %%
# Code for exercise 1 goes here
# *****************************
set.seed(123)
sixty <- nrow(wine) * 0.6
print(sixty)
train_ind <- sample(seq_len(nrow(wine)), size = sixty)
train <- wine[train_ind,]
test <- wine[-train_ind,]
test
train
# Out:
# [1] 959.4
#      fixed.acidity volatile.acidity citric.acid residual.sugar chlorides
# 5     7.4          0.700            0.00        1.90           0.076
# 6     7.4          0.660            0.00        1.80           0.075
# 8     7.3          0.650            0.00        1.20           0.065
# 12    7.5          0.500            0.36        6.10           0.071
# 14    7.8          0.610            0.29        1.60           0.114
# 18    8.1          0.560            0.28        1.70           0.368
# 23    7.9          0.430            0.21        1.60           0.106
# 24    8.5          0.490            0.11        2.30           0.084
# 25    6.9          0.400            0.14        2.40           0.085
# 26    6.3          0.390            0.16        1.40           0.080
# 30    7.8          0.645            0.00        2.00           0.082
# 33    8.3          0.655            0.12        2.30           0.083
# 35    5.2          0.320            0.25        1.80           0.103
# 46    4.6          0.520            0.15        2.10           0.054
# 47    7.7          0.935            0.43        2.20           0.114
# 48    8.7          0.290            0.52        1.60           0.113
# 49    6.4          0.400            0.23        1.60           0.066
# 51    8.8          0.660            0.26        1.70           0.074
# 52    6.6          0.520            0.04        2.20           0.069
# 53    6.6          0.500            0.04        2.10           0.068
# 57   10.2          0.420            0.57        3.40           0.070
# 58    7.5          0.630            0.12        5.10           0.111
# 60    7.3          0.390            0.31        2.40           0.074
# 63    7.5          0.520            0.16        1.90           0.085
# 64    7.0          0.735            0.05        2.00           0.081
# 65    7.2          0.725            0.05        4.65           0.086
# 66    7.2          0.725            0.05        4.65           0.086
# 69    9.3          0.320            0.57        2.00           0.074
# 70    8.0          0.705            0.05        1.90           0.074
# 75    9.7          0.320            0.54        2.50           0.094
# ⋮    ⋮             ⋮                ⋮           ⋮              ⋮
# 1535  6.6          0.560            0.14         2.4           0.064
# 1536  7.0          0.550            0.13         2.2           0.075
# 1539  6.2          0.640            0.09         2.5           0.081
# 1541  6.2          0.520            0.08         4.4           0.071
# 1543  6.7          0.855            0.02         1.9           0.064
# 1544 11.1          0.440            0.42         2.2           0.064
# 1545  8.4          0.370            0.43         2.3           0.063
# 1546  6.5          0.630            0.33         1.8           0.059
# 1548  6.3          0.600            0.10         1.6           0.048
# 1550  7.4          0.360            0.30         1.8           0.074
# 1553  6.3          0.680            0.01         3.7           0.103
# 1554  7.3          0.735            0.00         2.2           0.080
# 1556  7.0          0.560            0.17         1.7           0.065
# 1564  7.2          0.695            0.13         2.0           0.076
# 1566  6.7          0.670            0.02         1.9           0.061
# 1569  7.0          0.560            0.13         1.6           0.077
# 1572  6.4          0.380            0.14         2.2           0.038
# 1573  7.3          0.690            0.32         2.2           0.069
# 1567 normal
# 1033 bad
# 1116 normal
# 856  good
# 934  bad
# 455  bad
# 231  good
# ⋮    ⋮
# 526  bad
# 594  bad
# 137  bad
# 515  good
# 1265 normal
# 637  bad
# 825  bad
# 1155 normal
# 1378 normal
# 575  normal
# 1261 bad
# 644  bad
# 323  bad
# 1187 bad
# 1165 bad
# 846  bad
# 820  bad
# 1510 bad
# 1559 bad
# 1145 bad
# 1580 bad
# 1268 normal
# 102  normal
# 619  bad
# 678  bad
# 1119 normal
# 620  bad
# 1112 good
# 40   bad
# 926  good

# %% [markdown]
# **Exercise 2**: Create a formula for the prediction task. First predict using all of the variables other than the target. In order to avoid typing out all of the variables, you can use the following notation:
#
# ```splus
# target ~ .
# ```
#
# The "." tells `R` to use all other variables in the dataset (that are not the target) as inputs.

# %%
# Code for exercise 2 goes here
# *****************************
form <- taste ~ .

# %% [markdown]
# **Exercise 3**: Create a Decision Tree model using the `tree` function. Make sure that you pass the newly created formula as a parameter and specify the training data set. Be sure to name this object something (in the examples, we called it `tr`). Then run a summary on the object.

# %%
# Code for exercise 3 goes here
# *****************************

tr <- tree(form, data = train)
summary(tr)
# Out:
# Classification tree:
# tree(formula = form, data = train)
# Variables actually used in tree construction:
# [1] "alcohol"              "volatile.acidity"     "sulphates"
# [4] "chlorides"            "total.sulfur.dioxide"
# Number of terminal nodes:  10
# Residual mean deviance:  1.468 = 1393 / 949
# Misclassification error rate: 0.3264 = 313 / 959

# %% [markdown]
# Pay attention to the output of the summary.
#
# **Exercise 4**: What is the misclassification error rate of the tree using the **testing** set?

# %%
# Code for exercise 4 goes here
# *****************************

trtest <- tree(form, data = test)
summary(trtest)


print("misclassification error rate = 0.3344")
# Out:
# Classification tree:
# tree(formula = form, data = test)
# Variables actually used in tree construction:
# [1] "alcohol"              "sulphates"            "total.sulfur.dioxide"
# [4] "fixed.acidity"        "volatile.acidity"     "chlorides"
# [7] "citric.acid"          "density"
# Number of terminal nodes:  13
# Residual mean deviance:  1.383 = 867.2 / 627
# Misclassification error rate: 0.3344 = 214 / 640
# [1] "misclassification error rate = 0.3349"

# %% [markdown]
# **Exercise 5**: Now create a Naïve Bayes classifier using the formula and training data. Be sure to name this model something (in the other notebooks, we called it `m`).

# %%
# Code for exercise 5 goes here
# *****************************
m <- naiveBayes(form, data = train)
m
# Out:
# Naive Bayes Classifier for Discrete Predictors
#
# Call:
# naiveBayes.default(x = X, y = Y, laplace = laplace)
#
# A-priori probabilities:
# Y
#       bad      good    normal
# 0.4734098 0.1303441 0.3962461
#
# Conditional probabilities:
#         fixed.acidity
# Y            [,1]     [,2]
#   bad    8.191189 1.530286
#   good   8.928000 2.106771
#   normal 8.458947 1.834325
#
#         volatile.acidity
# Y             [,1]      [,2]
#   bad    0.5984141 0.1872713
#   good   0.4045200 0.1430999
#   normal 0.4914079 0.1687192
#
#         citric.acid
# Y             [,1]      [,2]
#   bad    0.2390749 0.1853319
#   good   0.3744800 0.1905444
#   normal 0.2882105 0.1950711
#
#         residual.sugar
# Y            [,1]     [,2]
#   bad    2.512445 1.298201
#   good   2.676400 1.299699
#   normal 2.471053 1.327730
#
#         chlorides
# Y              [,1]       [,2]
#   bad    0.09217401 0.05137602
#   good   0.07500800 0.02245443
#   normal 0.08388947 0.03630374
#
#         free.sulfur.dioxide
# Y            [,1]     [,2]
#   bad    16.43612 10.69295
#   good   14.34800 10.74075
#   normal 16.18553 10.24491
#
#         total.sulfur.dioxide
# Y            [,1]     [,2]
#   bad    53.25881 36.24222
#   good   36.41600 32.42365
#   normal 41.64474 25.59287
#
#         density
# Y             [,1]        [,2]
#   bad    0.9970553 0.001547489
#   good   0.9960550 0.002203826
#   normal 0.9966485 0.002043225
#
#         pH
# Y            [,1]      [,2]
#   bad    3.311057 0.1521247
#   good   3.286880 0.1573542
#   normal 3.312395 0.1519801
#
#         sulphates
# Y             [,1]      [,2]
#   bad    0.6209031 0.1747981
#   good   0.7485600 0.1372818
#   normal 0.6681842 0.1439680
#
#         alcohol
# Y             [,1]      [,2]
#   bad     9.942401 0.7196797
#   good   11.574133 0.9948421
#   normal 10.641535 1.0472273

# %% [markdown]
# **Exercise 6**: What is the misclassification error rate of the Naïve Bayes classifier using the **testing** set?

# %%
# Code for exercise 6 goes here
# *****************************

table(predict(m, test[,-c(12)]), test[,12])

testpredict <- predict(m, test[,-c(12)])
mean(testpredict != test$taste)
# Out:
#
#          bad good normal
#   bad    222    8     98
#   good     7   47     30
#   normal  61   37    130
# [1] 0.3765625

# %% [markdown]
# Take a look at the summary of the tree created in Exercise 3. It shows us the features that it used for the classification task.
#
# **Exercise 7**: Create a new formula that predicts `taste` using only the features that the decision tree defined. Be sure to name this formula something different from the old formula.

# %%
# Code for exercise 7 goes here
# *****************************

form2 = taste ~ alcohol + volatile.acidity + sulphates + chlorides + total.sulfur.dioxide

# %% [markdown]
# **Exercise 8**: Now create a Naïve Bayes classifier using this pruned formula and training data. Be sure to name this model something other than your original Naive Bayes model.

# %%
# Code for exercise 8 goes here
# *****************************


m2 <- naiveBayes(form2, data = train)
table(predict(m2, test[,-c(12)]), test[,12])
testpredict2 <- predict(m2, test[,-c(12)])
mean(testpredict2 != test$taste)
# Out:
#
#          bad good normal
#   bad    205    4     69
#   good     6   42     24
#   normal  79   46    165
# [1] 0.35625

# %% [markdown]
# **Exercise 9**: Does using only these select features create a better model according to the testing data misclassification error rate?

# %%
# Code for exercise 9 goes here
# *****************************
testpredict2 <- predict(m2, test[,-c(12)])
mean(testpredict2 != test$taste)

("Yes, misclassification error rate is 0.35625 when only looking at the features that the tree used, while misclassification error rate is 0.3765625 when looking at all features ")
# Out:
# [1] 0.35625
# [1] "Yes, misclassification error rate is 0.35625 when only looking at the features that the tree used, while misclassification error rate is 0.3765625 when looking at all features "

# %% [markdown]
# # Save your noteboot, then `File > Close and Halt`
